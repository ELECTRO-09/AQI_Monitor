# %% [markdown]
# # Air Quality Analysis Using Python

# %% [markdown]
# ####

# %%
import requests
import pandas as pd
import matplotlib.pyplot as plt
import datetime

# %% [markdown]
# ### API Key is Fetched by signing up to Open Weather Map.

# %%
API_KEY='c31f6c800d52bfdc303ef7ccf8a73eb5'
CITY='Mysore' # City of your Choice

# %% [markdown]
# ## Fetch the Data

# %%
def fetch_aqi_data(api_key,city,start,end):
    # Get the Latitude and Longitude for the City
    geo_url=f'http://api.openweathermap.org/geo/1.0/direct?q={city}&limit=1&appid={api_key}'
    geo_response=requests.get(geo_url)
    geo_data=geo_response.json()
    if len(geo_data)==0:
        raise ValueError(f"city {city} not found")

    lat=geo_data[0]['lat']
    lon=geo_data[0]['lon']

    url=f'http://api.openweathermap.org/data/2.5/air_pollution/history?lat={lat}&lon={lon}&start={start}&end={end}&appid={api_key}'
    response=requests.get(url)
    data=response.json()
    return data
    
# Define the start and end Timestamps for Historical Data(Example-- Last 7 days)
end_time=int(datetime.datetime.now().timestamp())
start_time=end_time-(7*24*60*60) # 7 days Ago

# Fetch AQI Data
aqi_data=fetch_aqi_data(API_KEY,CITY,start_time,end_time)

aqi_data
# Out:
# {'coord': {'lon': 76.6554, 'lat': 12.3052},
#  'list': [{'main': {'aqi': 1},
#    'components': {'co': 417.23,
#     'no': 1.45,
#     'no2': 6.85,
#     'o3': 50.07,
#     'so2': 3.93,
#     'pm2_5': 4.54,
#     'pm10': 6.2,
#     'nh3': 2.15},
#    'dt': 1731477600},
#   {'main': {'aqi': 2},
#    'components': {'co': 387.19,
#     'no': 0.85,
#     'no2': 5.74,
#     'o3': 63.66,
#     'so2': 3.73,
#     'pm2_5': 5.47,
#     'pm10': 6.72,
#     'nh3': 1.76},
#    'dt': 1731481200},
#   {'main': {'aqi': 2},
#    'components': {'co': 383.85,
#     'no': 0.46,
#     'no2': 6.08,
#     'o3': 68.66,
#     'so2': 3.76,
#     'pm2_5': 6.81,
#     'pm10': 7.93,
#     'nh3': 1.71},
#    'dt': 1731484800},
#   {'main': {'aqi': 2},
#    'components': {'co': 373.84,
#     'no': 0.18,
#     'no2': 6.6,
#     'o3': 65.09,
#     'so2': 3.55,
#     'pm2_5': 5.64,
#     'pm10': 6.59,
#     'nh3': 1.57},
#    'dt': 1731488400},
#   {'main': {'aqi': 1},
#    'components': {'co': 373.84,
# ...

# %% [markdown]
# ## Process and Analyze the Data

# %%
# Extract Relavent Data
def process_aqi_data(data):
    records=[]
    for item in data['list']:
        dt=datetime.datetime.fromtimestamp(item['dt'])
        aqi=item['main']['aqi']
        components=item['components']
        record={'datetime':dt,'aqi':aqi,
                **components}
        records.append(record)
    return pd.DataFrame(records)
    
aqi_df=process_aqi_data(aqi_data)

# Plot AQI Over Time
plt.figure(figsize=(12,6))
plt.plot(aqi_df['datetime'],aqi_df['aqi'],marker='D',linestyle='-')
plt.title(f'Air Quality Index (AQI) of {CITY}')
plt.xlabel('Date')
plt.ylabel('AQI')
plt.grid(True)
plt.show()

# %% [markdown]
# ## Plot Individual Components

# %%
# Plot Individual Components
components=['pm2_5','pm10','no2','so2','o3','co']
for component in components:
    plt.figure(figsize=(12,6))
    plt.plot(aqi_df['datetime'],aqi_df[component],marker='o',linestyle='-')
    plt.title(f'{component.upper()} (µg/m³)')
    plt.grid(True)
    plt.show()

# %% [markdown]
# ## Plot Multiple Components in a single plot for Comparison

# %%
plt.figure(figsize=(12,6))
for component in components:
  plt.plot(aqi_df['datetime'],aqi_df[component],marker='o',linestyle='-',label=component.upper())
plt.title(f'Air Quality Components in {CITY}')
plt.xlabel('Date')
plt.ylabel('Concentration(μg/m³)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ## Scatter Plot for AQI vs Individual Components

# %%
plt.figure(figsize=(12,6))
for component in components:
  plt.scatter(aqi_df[component],aqi_df['aqi'],label=component.upper())
plt.title(f'AQI v/s Pollutant Levels in {CITY}')
plt.xlabel('Pollutant Level (μg/m³)')
plt.ylabel('AQI')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### To Summarize- The required libraries like pandas(Version 2.2.3), requests, datetime have been imported.
# ### Signed up at Open Wather map Website and got the API Key (Free). Later the API key and City name was used
# ### in a custom function to Perform Data Analysis by Retrieving the data like particle matter, components(such as Oxygen , Carbon Monoxide, Ozone, etc
# ### Finally the data was Visualised with respect to Components and the AQI of the Mysore City (Karnataka Region)
#
# #### - Created by ELECTRO
